# %% [markdown]
# # MTMT co-authorship Network

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import sys
import os
import pathlib
import glob

import json

import networkx as nx

import re
import uuid

# %%
file = open("data/publication2.json","rt",encoding="utf-8")
data = json.load(file)

file.close()

# %%
data.keys()
# Out:
# dict_keys(['labelLang', 'responseDate', 'paging', 'content'])

# %%
len(data['content'])
# Out:
# 5000

# %%
for i in data['content'][0].keys():
    print(i)
# Out:
# otype
# mtid
# status
# published
# unhandledTickets
# deleted
# lastRefresh
# lastModified
# created
# creator
# lastDuplumOK
# lastDuplumSearch
# validated
# validator
# core
# citation
# publicationPending
# type
# subType
# category
# languages
# firstAuthor
# authorships
# title
# identifiers
# journal
# volume
# issue
# internalId
# firstPageOrInternalIdForSort
# pageLength
# publishedYear
# abstractText
# subjects
# keywords
# digital
# printed
# sourceYear
# foreignEdition
# foreignLanguage
# fullPublication
# conferencePublication
# nationalOrigin
# missingAuthor
# oaType
# oaCheckDate
# oaFree
# oaLink
# citationCount
# citationCountUnpublished
# citationCountWoOther
# independentCitCountWoOther
# nationalOriginCitationCount
# foreignEditionCitationCount
# doiCitationCount
# wosCitationCount
# scopusCitationCount
# wosScopusCitationCount
# wosScopusCitationCountWoOther
# wosScopusIndependentCitationCount
# wosScopusIndependentCitationCountWoOther
# independentCitationCount
# selfCitationCount
# unhandledCitationCount
# citingPubCount
# independentCitingPubCount
# citingPubCountWoOther
# independentCitingPubCountWoOther
# unhandledCitingPubCount
# citedPubCount
# citedCount
# ratings
# ratingsForSort
# hasCitationDuplums
# userChangeableUntil
# directInstitutesForSort
# ownerAuthorCount
# ownerInstituteCount
# directInstituteCount
# authorCount
# contributorCount
# hasQualityFactor
# link
# label
# template
# template2

# %%
print(len(data['content']))
# Out:
# 5000

# %%
data['content'][0]['label']
# Out:
# 'Aad G et al. Search for exotic decays of the Higgs boson into long-lived particles in pp collisions at root s=13 TeV using displaced vertices in the ATLAS inner detector. (2021) JOURNAL OF HIGH ENERGY PHYSICS 1126-6708 1029-8479 2021 11'

# %%
data['content'][0]['published']
# Out:
# True

# %%
data['content'][0].keys()
# Out:
# dict_keys(['otype', 'mtid', 'status', 'published', 'unhandledTickets', 'deleted', 'lastRefresh', 'lastModified', 'created', 'creator', 'lastDuplumOK', 'lastDuplumSearch', 'validated', 'validator', 'core', 'citation', 'publicationPending', 'type', 'subType', 'category', 'languages', 'firstAuthor', 'authorships', 'title', 'identifiers', 'journal', 'volume', 'issue', 'internalId', 'firstPageOrInternalIdForSort', 'pageLength', 'publishedYear', 'abstractText', 'subjects', 'keywords', 'digital', 'printed', 'sourceYear', 'foreignEdition', 'foreignLanguage', 'fullPublication', 'conferencePublication', 'nationalOrigin', 'missingAuthor', 'oaType', 'oaCheckDate', 'oaFree', 'oaLink', 'citationCount', 'citationCountUnpublished', 'citationCountWoOther', 'independentCitCountWoOther', 'nationalOriginCitationCount', 'foreignEditionCitationCount', 'doiCitationCount', 'wosCitationCount', 'scopusCitationCount', 'wosScopusCitationCount', 'wosScopusCitationCountWoOther', 'wosScopusIndependentCitationCount', 'wosScopusIndependentCitationCountWoOther', 'independentCitationCount', 'selfCitationCount', 'unhandledCitationCount', 'citingPubCount', 'independentCitingPubCount', 'citingPubCountWoOther', 'independentCitingPubCountWoOther', 'unhandledCitingPubCount', 'citedPubCount', 'citedCount', 'ratings', 'ratingsForSort', 'hasCitationDuplums', 'userChangeableUntil', 'directInstitutesForSort', 'ownerAuthorCount', 'ownerInstituteCount', 'directInstituteCount', 'authorCount', 'contributorCount', 'hasQualityFactor', 'link', 'label', 'template', 'template2'])

# %%
list(data['content'][0].keys())[47]
# Out:
# 'oaLink'

# %%
for i in np.arange(35,len(list(data['content'][0].keys()))):
    print(list(data['content'][0].keys())[i], "\n\t" , data['content'][0][list(data['content'][0].keys())[i]])
# Out:
# digital
# 	 None
# printed
# 	 None
# sourceYear
# 	 2022
# foreignEdition
# 	 True
# foreignLanguage
# 	 True
# fullPublication
# 	 True
# conferencePublication
# 	 False
# nationalOrigin
# 	 True
# missingAuthor
# 	 False
# oaType
# 	 GOLD
# oaCheckDate
# 	 2022-02-09
# oaFree
# 	 True
# oaLink
# 	 https://doi.org/10.1007%2FJHEP11%282021%29229
# citationCount
# 	 0
# citationCountUnpublished
# 	 0
# citationCountWoOther
# 	 0
# independentCitCountWoOther
# 	 0
# nationalOriginCitationCount
# 	 0
# foreignEditionCitationCount
# 	 0
# doiCitationCount
# 	 0
# wosCitationCount
# 	 0
# scopusCitationCount
# 	 0
# wosScopusCitationCount
# 	 0
# wosScopusCitationCountWoOther
# 	 0
# wosScopusIndependentCitationCount
# 	 0
# wosScopusIndependentCitationCountWoOther
# 	 0
# independentCitationCount
# 	 0
# selfCitationCount
# 	 0
# unhandledCitationCount
# 	 0
# citingPubCount
# 	 0
# independentCitingPubCount
# 	 0
# citingPubCountWoOther
# 	 0
# independentCitingPubCountWoOther
# 	 0
# unhandledCitingPubCount
# 	 0
# citedPubCount
# 	 1
# citedCount
# 	 1
# ratings
# 	 [{'otype': 'SjrRating', 'mtid': 11239527, 'link': '/api/sjrrating/11239527', 'label': 'sjr:Q2 (2021) Scopus - Nuclear and High Energy Physics JOURNAL OF HIGH ENERGY PHYSICS 1126-6708 1029-8479', 'listPos': 20, 'rankValue': 0.49, 'type': 'journal', 'ratingType': {'otype': 'RatingType', 'mtid': 10002, 'link': '/api/ratingtype/10002', 'label': 'sjr', 'code': 'sjr', 'published': True, 'snippet': True}, 'subject': {'otype': 'ClassificationExternal', 'mtid': 3106, 'link': '/api/classificationexternal/3106', 'label': 'Scopus - Nuclear and High Energy Physics', 'published': True, 'oldId': 3106, 'snippet': True}, 'ranking': 'Q2', 'calculation': 'FROM_LAST_YEAR', 'published': True, 'snippet': True}]
# ratingsForSort
# 	 Q2
# hasCitationDuplums
# 	 False
# userChangeableUntil
# 	 2022-01-02T06:45:41.796+0000
# directInstitutesForSort
# 	 ATLAS Collaboration (Wigner FK / RMI)
# ownerAuthorCount
# 	 1
# ownerInstituteCount
# 	 12
# directInstituteCount
# 	 1
# authorCount
# 	 2870
# contributorCount
# 	 0
# hasQualityFactor
# 	 True
# link
# 	 /api/publication/32557184
# label
# 	 Aad G et al. Search for exotic decays of the Higgs boson into long-lived particles in pp collisions at root s=13 TeV using displaced vertices in the ATLAS inner detector. (2021) JOURNAL OF HIGH ENERGY PHYSICS 1126-6708 1029-8479 2021 11
# template
# 	 <div class="JournalArticle Publication short-list"> <div class="authors"> <span class="author-name" > Aad, G </span> <span class="author-type"> </span> ; <span class="author-name" > Abbott, B </span> <span class="author-type"> </span> ; <span class="author-name" > Abbott, DC </span> <span class="author-type"> </span> ; <span class="author-name" > Abud, AA </span> <span class="author-type"> </span> ; <span class="author-name" > Abeling, K </span> <span class="author-type"> </span> ; <span class="author-name" > Abhayasinghe, DK </span> <span class="author-type"> </span> ; <span class="author-name" > Abidi, SH </span> <span class="author-type"> </span> ; <span class="author-name" > Abramowicz, H </span> <span class="author-type"> </span> ; <span class="author-name" > Abreu, H </span> <span class="author-type"> </span> ; <span class="author-name" > Abulaiti, Y </span> <span class="author-type"> </span> et al. </div ><div class="title"><a href="/gui2/?mode=browse&params=publication;32557184" mtid="32557184" target="_blank">Search for exotic decays of the Higgs boson into long-lived particles in pp collisions at root s=13 TeV using displaced vertices in the ATLAS inner detector</a></div> <div class="pub-info"> <span class="journal-title">JOURNAL OF HIGH ENERGY PHYSICS</span> <span class="journal-volume">2021</span> : <span class="journal-issue">11</span> <span class="page"> Paper: 229 , 41 p. </span> <span class="year">(2021)</span> </div> <div class="pub-end"><div class="identifier-list"> <span class="identifiers"> <span class="id identifier oa_GREEN" title=" Green "> <a style="color:blue" title="10.1007/JHEP11(2021)229" target="_blank" href="https://doi.org/10.1007%2FJHEP11%282021%29229"> DOI </a> </span> <span class="id identifier oa_none" title="none"> <a style="color:blue" title="000729777000001" target="_blank" href="http://gateway.isiknowledge.com/gateway/Gateway.cgi?&GWVersion=2&SrcAuth=CustomerName&SrcApp=CustomerName&DestLinkType=FullRecord&KeyUT=000729777000001&DestApp=WOS"> WoS </a> </span> <span class="id identifier oa_none" title="none"> <a style="color:blue" title="85121293715" target="_blank" href="http://www.scopus.com/record/display.url?origin=inward&eid=2-s2.0-85121293715"> Scopus </a> </span> <span class="id identifier oa_none" title="none"> <a style="color:blue" title="2021JHEP...11..229A" target="_blank" href="http://adsabs.harvard.edu/abs/2021JHEP...11..229A"> ADS </a> </span> <span class="id identifier oa_none" title="none"> <a style="color:blue" title="2107.06092" target="_blank" href="http://arxiv.org/abs/2107.06092"> arXiv </a> </span> </span> </div> <span class="short-pub-prop-list"> <span class="short-pub-mtid"> Közlemény:32557184 </span> <span class="status-holder"><span class="status-data status-VALIDATED"> Egyeztetett </span></span> <span class="pub-core">Forrás Idéző</span> <span class="pub-type">Folyóiratcikk (Sokszerzős vagy csoportos szerzőségű szakcikk ) </span> <!-- && !record.category.scientific --> <span class="pub-category">Tudományos</span> </span> </div> </div>
# template2
# 	 <div class="JournalArticle Publication long-list"> <div class="authors"> <img title="Forrásközlemény" style="float: left" src="/frontend/resources/grid/publication-core-icon.png"> <img title="Idézőközlemény" style="float: left" src="/frontend/resources/grid/publication-citation-icon.png"> <div class="autype autype0"> <span class="author-name" >Aad G </span> ;&nbsp;&nbsp;&nbsp; <span class="author-name" mtid="10007566"><a href="/gui2/?type=authors&mode=browse&sel=10007566" target="_blank">Toth J (<span class="authorship-author-name">Tóth József</span> <span class="authorAux-mtmt"> Kísérleti részecskefizika</span>) </a> </span> <span class="author-affil"><span title="Wigner Fizikai Kutatóközpont">Wigner FK</span>/<span title="Részecske- és Magfizikai Intézet">RMI</span>/<span title="Kollaborációk">Kollaborációk</span>/ATLAS Collaboration</span> ;&nbsp;&nbsp;&nbsp; et al. (2,870) </div> <div class="autype autype-29"> Kollaborációs szervezet: <span class="author-affil">ATLAS Collaboration</span> </div> <div><a target="_blank" href="/api/publication/32557184?labelLang=hun">Összes szerző</a></div> </div> <div class="title"><a href="/gui2/?mode=browse&params=publication;32557184" target="_blank">Search for exotic decays of the Higgs boson into long-lived particles in pp collisions at root s=13 TeV using displaced vertices in the ATLAS inner detector</a></div> <div> <span class="journal-title">JOURNAL OF HIGH ENERGY PHYSICS</span> <span class="journal-issn">(<a target="_blank" href="https://portal.issn.org/resource/ISSN/1126-6708">1126-6708</a> <a target="_blank" href="https://portal.issn.org/resource/ISSN/1029-8479">1029-8479</a>)</span>: <span class="journal-volume">2021</span> <span class="journal-issue">11</span> <span class="page"> Paper 229. 41 p. </span> <span class="year">(2021)</span> <br> </span> </div> <div class="pub-footer">  <span class="language" xmlns="http://www.w3.org/1999/html">Nyelv: Angol | </span> <span class="identifiers"> <span class="id identifier oa_GREEN" title=" Green "> <a style="color:blue" title="10.1007/JHEP11(2021)229" target="_blank" href="https://doi.org/10.1007%2FJHEP11%282021%29229"> DOI </a> </span> <span class="id identifier oa_none" title="none"> <a style="color:blue" title="000729777000001" target="_blank" href="http://gateway.isiknowledge.com/gateway/Gateway.cgi?&GWVersion=2&SrcAuth=CustomerName&SrcApp=CustomerName&DestLinkType=FullRecord&KeyUT=000729777000001&DestApp=WOS"> WoS </a> </span> <span class="id identifier oa_none" title="none"> <a style="color:blue" title="85121293715" target="_blank" href="http://www.scopus.com/record/display.url?origin=inward&eid=2-s2.0-85121293715"> Scopus </a> </span> <span class="id identifier oa_none" title="none"> <a style="color:blue" title="2021JHEP...11..229A" target="_blank" href="http://adsabs.harvard.edu/abs/2021JHEP...11..229A"> ADS </a> </span> <span class="id identifier oa_none" title="none"> <a style="color:blue" title="2107.06092" target="_blank" href="http://arxiv.org/abs/2107.06092"> arXiv </a> </span> </span>   <div class="publication-citation"> <a target="_blank" href="/api/publication?cond=citations.related;eq;32557184&sort=publishedYear,desc&sort=title"> Idézett közlemények száma: 1 </a> </div> <div class="mtid"><span class="long-pub-mtid">Közlemény: 32557184</span> | <span class="status-data status-VALIDATED"> Egyeztetett </span> Forrás Idéző | <span class="type-subtype">Folyóiratcikk ( Sokszerzős vagy csoportos szerzőségű szakcikk ) </span> | Tudományos </span> | <span class="publication-sourceOfData">RIS-Egyéb</span> </div> <div class="lastModified">Utolsó módosítás: 2022.01.03. 07:45 Tomcsik Adrienn (Wigner-RMI admin5) </div> </div></div>

# %%
data['content'][0][list(data['content'][0].keys())[26]]
# Out:
# 0

# %%
data['content'][0]['title']
# Out:
# 'Search for exotic decays of the Higgs boson into long-lived particles in pp collisions at root s=13 TeV using displaced vertices in the ATLAS inner detector'

# %%
data['responseDate']
# Out:
# '2022-02-17 13:33'

# %%
data['paging']
# Out:
# {'last': True,
#  'first': True,
#  'totalPages': 1,
#  'totalElements': 5000,
#  'totalEstimatedElements': 110000,
#  'size': 5000,
#  'number': 1,
#  'numberOfElements': 5000,
#  'sort': [{'direction': 'DESC',
#    'property': 'publishedYear',
#    'ascending': False},
#   {'direction': 'ASC', 'property': 'firstAuthor', 'ascending': True}]}

# %%
print(data['content'][0]['authorships'][0]['mtid'])
print(data['content'][0]['authorships'][0]['givenName'])
print(data['content'][0]['authorships'][0]['familyName'])
print(data['content'][0]['authorships'][0]['label'])
# Out:
# 99807928
# G
# Aad
# Aad, G

# %%
data['content'][34]['authorships'][0]
# Out:
# {'otype': 'PersonAuthorship',
#  'mtid': 95886196,
#  'link': '/api/authorship/95886196',
#  'label': 'Abdullah, S. Alshammari ✉ [Alshammari, Abdullah Saber (Educational science), szerző] Neveléstudományi Doktori Iskola (SZTE / DI)',
#  'listPosition': 1,
#  'share': 0.33333334,
#  'first': True,
#  'last': False,
#  'corresponding': True,
#  'author': {'otype': 'Author',
#   'mtid': 10064710,
#   'link': '/api/author/10064710',
#   'label': 'Alshammari Abdullah Saber (Educational science)',
#   'familyName': 'Alshammari',
#   'givenName': 'Abdullah Saber',
#   'published': True,
#   'oldId': 10064710,
#   'snippet': True},
#  'familyName': 'Abdullah',
#  'givenName': 'S. Alshammari',
#  'authorTyped': True,
#  'editorTyped': False,
#  'otherTyped': False,
#  'type': {'otype': 'AuthorshipType',
#   'mtid': 1,
#   'link': '/api/authorshiptype/1',
#   'label': 'Szerző',
#   'code': 0,
#   'published': True,
#   'oldId': 0,
#   'snippet': True},
#  'published': False,
#  'snippet': True}

# %%
data['content'][0]['authorships'][0]
# Out:
# {'otype': 'PersonAuthorship',
#  'mtid': 99807928,
#  'link': '/api/authorship/99807928',
#  'label': 'Aad, G',
#  'listPosition': 1,
#  'share': 0.0,
#  'first': True,
#  'last': False,
#  'corresponding': False,
#  'familyName': 'Aad',
#  'givenName': 'G',
#  'authorTyped': True,
#  'editorTyped': False,
#  'otherTyped': False,
#  'type': {'otype': 'AuthorshipType',
#   'mtid': 1,
#   'link': '/api/authorshiptype/1',
#   'label': 'Szerző',
#   'code': 0,
#   'published': True,
#   'oldId': 0,
#   'snippet': True},
#  'published': False,
#  'snippet': True}

# %%
temp_mem = []

for i in range(len(data['content'][0]['authorships'])):
    temp_mem.append(data['content'][0]['authorships'][i]['share'])

# %%
np.unique(temp_mem)
# Out:
# array([0.])

# %% [markdown]
# They are rather inconsistent in how well these object are defined.

# %%
110000/5000
# Out:
# 22.0

# %%
sub_mem = []
for i in range(len(data['content'])):
    sub_mem.append(len(data['content'][i]['authorships']))
sub_mem = np.array(sub_mem)

# %%
print(np.mean(sub_mem), "+/-", np.var(sub_mem)**(1/2))
# Out:
# 19.9854 +/- 187.9649701057088

# %%
plt.figure(figsize=(14,7))

plt.title("Distribution of Number of Authors per Paper \nFrom Most Recent 5000 papers", fontsize=24)

plt.hist(sub_mem, bins=101)

plt.xlabel("Number of Authors", fontsize=20)
plt.ylabel("Occurence", fontsize=20)
plt.tick_params(labelsize=18,axis="both",size=17)

plt.yscale("log")
plt.grid(linestyle="--")

plt.savefig("figs/dist_from_5000sample.pdf",format="pdf",bbox_inches="tight")
plt.show()

# %% [markdown]
# ## How to store tables?
#
# How should i store the linklist and the decoding?
#
# | startNode | endNode | time | weight |
# | --- | --- | --- | --- |
# | author1.mtid | author2.mtid | yearOfpublication | 0.01 |
# | author1.mtid | author3.mtid | yearOfpublication | 0.1 |
# | ... | ... | ... | ... |
#
# This template may work, but its not good if the `mtid` is not unique to a given author -> might need to test this!
#
# For the decoding table, the given table should be sufficient:
#
# | number | Name |
# | --- | --- |
# | 56 | Adam G. Taylor |
# | ... | ... |

# %% [markdown]
# Some modifications: rather than storing uuids as strings, I switched to using integers (namely numpy's uint32 bit integers) which requires (which is a correct looking estimate):

# %%
str(170000000 * 4 /1024 / 1024) + ' MB'
# Out:
# '648.49853515625 MB'

# %%
temp_mem = []
r = re.compile(r"\s+", re.MULTILINE)
count = 0
for i in range(len(data['content'])):
    for j in range(len(data['content'][i]['authorships'])):
        if (data['content'][i]['authorships'][j]['otype'] == 'PersonAuthorship'):
            string_to_add = '' 
            if 'givenName' in data['content'][i]['authorships'][j]:
                string_to_add += str(data['content'][i]['authorships'][j]['givenName']) + ' '
            if 'familyName' in data['content'][i]['authorships'][j]:
                string_to_add += str(data['content'][i]['authorships'][j]['familyName'])
            temp_mem.append(r.sub("",string_to_add))
            
        
temp_mem = list(np.unique(temp_mem))
temp_mem = dict(zip(temp_mem, np.array(np.arange(len(temp_mem)),dtype=np.uint32 )) )

# %%
temp_mem
# Out:
# {'A-EErson-Bensan': 0,
#  'A.-M.Bachmann': 1,
#  'A.A.Abud': 2,
#  'A.A.Affolder': 3,
#  'A.A.Capon': 4,
#  'A.A.Ciobanu': 5,
#  'A.A.Elliot': 6,
#  'A.A.Galakhova': 7,
#  'A.A.Geanta': 8,
#  'A.A.Gorn': 9,
#  'A.A.Grillo': 10,
#  'A.A.Minaenko': 11,
#  'A.A.Myers': 12,
#  'A.A.P.Jimenez': 13,
#  'A.A.P.Suaide': 14,
#  'A.A.Pabon': 15,
#  'A.A.Snesarev': 16,
#  'A.A.Solodkov': 17,
#  'A.A.Sztuc': 18,
#  'A.A.Talyshev': 19,
#  'A.AbedAbud': 20,
#  'A.Adams': 21,
#  'A.Adeboye': 22,
#  'A.Adiguzel': 23,
#  'A.Adler': 24,
#  'A.Aggarwal': 25,
#  'A.Ahmad': 26,
#  'A.Ain': 27,
#  'A.Akindinov': 28,
#  'A.Al-awar': 29,
#  'A.Albert': 30,
#  'A.Alegro': 31,
#  'A.Alfonsi': 32,
#  'A.Algora': 33,
#  'A.Ali': 34,
#  'A.Alici': 35,
#  'A.Alimkhanova': 36,
#  'A.Alkin': 37,
#  'A.Allocca': 38,
#  'A.Aloisio': 39,
#  'A.Alonso': 40,
#  'A.Alunno': 41,
#  'A.Amato': 42,
#  'A.Ambler': 43,
#  'A.Ananyeva': 44,
#  'A.Anderson': 45,
#  'A.Andics': 46,
#  'A.Andreazza': 47,
#  'A.Andronic': 48,
#  'A.Angerami': 49,
#  'A.Anjam': 50,
#  'A.Annovi': 51,
#  'A.Arance': 52,
#  'A.Aratari': 53,
#  'A.Arcones': 54,
#  'A.Ariga': 55,
#  'A.Arkhipov': 56,
#  'A.Armstrong': 57,
#  'A.Attarbaschi': 58,
#  'A.Augustinus': 59,
#  'A.Avila-Alvarez': 60,
#  'A.B.Fenyuk': 61,
#  'A.B.G.Shitrit': 62,
#  'A.B.Kurepin': 63,
#  'A.B.McDonald': 64,
#  'A.B.Yelikar': 65,
#  'A.B.Zimmerman': 66,
#  'A.Babangida': 67,
#  'A.Bachiu': 68,
#  'A.Badala': 69,
#  'A.Badalà': 70,
#  'A.Badea': 71,
#  'A.Bai': 72,
#  'A.Bakshi': 73,
#  'A.Balbino': 74,
#  'A.Baldeschi': 75,
#  'A.Baldisseri': 76,
#  'A.Balduzzi': 77,
#  'A.Balsamo': 78,
#  'A.Bandyopadhyay': 79,
#  'A.Barg': 80,
#  'A.Baroncelli': 81,
#  'A.BarthaFerenc': 82,
#  'A.Basalaev': 83,
#  'A.Basan': 84,
#  'A.Bassalat': 85,
#  'A.Basti': 86,
#  'A.Baudesson-Stella': 87,
#  'A.Bayirli': 88,
#  'A.Bayo': 89,
#  'A.Bazilevsky': 90,
#  'A.Bean': 91,
#  'A.Beddall': 92,
#  'A.Behera': 93,
#  'A.Beishuizen': 94,
#  'A.Bekkelien': 95,
#  'A.Bellanger': 96,
#  'A.Beller': 97,
#  'A.Bellerive': 98,
#  'A.Beloshapkin': 99,
#  'A.Benecke': 100,
#  'A.Benndorf': 101,
#  'A.Bercuci': 102,
#  'A.Berdnikov': 103,
#  'A.Berdnikova': 104,
#  'A.Berkics': 105,
#  'A.Bernard': 106,
#  'A.Berthold': 107,
#  'A.Bertolini': 108,
#  'A.Best': 109,
#  'A.Bethani': 110,
#  'A.Betti': 111,
#  'A.Bezdek': 112,
#  'A.Bhardwaj': 113,
#  'A.Bhasin': 114,
#  'A.Bialek': 115,
#  'A.Bianchi': 116,
#  'A.Bieryla': 117,
#  'A.Bilandzic': 118,
#  'A.Bingul': 119,
#  'A.Biondini': 120,
#  'A.Bisht': 121,
#  'A.Bitadze': 122,
#  'A.Blanchet': 123,
#  'A.Blondel': 124,
#  'A.Blue': 125,
#  'A.Boccaletti': 126,
#  'A.Boeltzig': 127,
#  'A.Bogdanov': 128,
#  'A.Bolozdynya': 129,
#  'A.Bombrun': 130,
#  'A.Bonfanti': 131,
#  'A.Bonyár': 132,
#  'A.Boonen': 133,
#  'A.Borisov': 134,
#  'A.Borissov': 135,
#  'A.Bosio': 136,
#  'A.Boveia': 137,
#  'A.Bozzi': 138,
#  'A.Bragaglia': 139,
#  'A.Bramley': 140,
#  'A.Branch': 141,
#  'A.Brandeker': 142,
#  'A.Bravar': 143,
#  'A.Bressan': 144,
#  'A.Brillet': 145,
#  'A.Bruni': 146,
#  'A.Bubak': 147,
#  'A.Buchin': 148,
#  'A.Budzillo': 149,
#  'A.Buikema': 150,
#  'A.Buonanno': 151,
#  'A.Burlacu': 152,
#  'A.Butrym': 153,
#  'A.Buzatu': 154,
#  'A.Bódi': 155,
#  'A.C.A.Lee': 156,
#  'A.C.Baylor': 157,
#  'A.C.Cameron': 158,
#  'A.C.Dudder': 159,
#  'A.C.Forti': 160,
#  'A.C.Freegard': 161,
#  'A.C.Green': 162,
#  'A.C.Jenkins': 163,
#  'A.C.Kaboth': 164,
#  'A.C.Koenig': 165,
#  'A.C.Konig': 166,
#  'A.C.König': 167,
#  'A.C.Lanzafame': 168,
#  'A.C.Martyniuk': 169,
#  'A.C.Mignerey': 170,
#  'A.C.Robin': 171,
#  'A.C.Ruggeri': 172,
#  'A.C.Schaffer': 173,
#  'A.C.Utina': 174,
#  'A.Caciolli': 175,
#  'A.Calandri': 176,
#  'A.Caldwell': 177,
#  'A.Caliva': 178,
#  'A.Caltabiano': 179,
#  'A.Campillay': 180,
#  'A.Camplani': 181,
#  'A.Canepa': 182,
#  'A.Canesse': 183,
#  'A.Cappa': 184,
#  'A.Caratelli': 185,
#  'A.Carbone': 186,
#  'A.Carls': 187,
#  'A.Carrer': 188,
#  'A.Cassese': 189,
#  'A.Castro-Ginard': 190,
#  'A.Catinaccio': 191,
#  'A.Cattai': 192,
#  'A.Cellino': 193,
#  'A.Cerri': 194,
#  'A.Cervelli': 195,
#  'A.Cervera': 196,
#  'A.Chappell': 197,
#  'A.Charl': 198,
#  'A.Chauvin': 199,
#  'A.Chen': 200,
#  'A.Cheplakov': 201,
#  'A.Chiappini': 202,
#  'A.Chiarucci': 203,
#  'A.Chiavassa': 204,
#  'A.Chibirov': 205,
#  'A.Chincarini': 206,
#  'A.Chitan': 207,
#  'A.Chiummo': 208,
#  'A.Ciocio': 209,
#  'A.Cirone': 210,
#  'A.Clark': 211,
#  'A.Coccaro': 212,
#  'A.Cody': 213,
#  'A.Cogoni': 214,
#  'A.Collu': 215,
#  'A.Colombo': 216,
#  'A.Corduneanu': 217,
#  'A.Corsi': 218,
#  'A.Csemer': 219,
#  'A.Csore': 220,
#  'A.Cudd': 221,
#  'A.Cueto': 222,
#  'A.Cumming': 223,
#  'A.Czajlik': 224,
#  'A.Czarnecka': 225,
#  'A.Czigola': 226,
#  'A.Czirják': 227,
#  "A.D'Onofrio": 228,
#  "A.D'onofrio": 229,
#  'A.D.C.BellHechavarria': 230,
#  'A.D.Ciaccio': 231,
#  'A.D.Earle': 232,
#  'A.D.Frawley': 233,
#  'A.D.Girolamo': 234,
#  'A.D.Huddart': 235,
#  'A.D.Luca': 236,
#  'A.D.Marino': 237,
#  'A.D.Mihalca': 238,
#  'A.D.Pilkington': 239,
#  'A.D.Salman': 240,
#  'A.D.Sedie': 241,
#  'A.D.Sherman': 242,
#  'A.D.Silva': 243,
#  'A.D.Sándor': 244,
#  'A.D.Viets': 245,
#  'A.Dabrowska': 246,
#  'A.Dainese': 247,
#  'A.Dana': 248,
#  'A.Daniel': 249,
#  'A.Danu': 250,
#  'A.Dapergolas': 251,
#  'A.Das': 252,
#  'A.Dasgupta': 253,
#  'A.Datta': 254,
#  'A.Dattagupta': 255,
#  'A.DeCaro': 256,
#  'A.Deblaere': 257,
#  'A.Deisting': 258,
#  'A.Delbart': 259,
#  'A.Delboulbe': 260,
#  'A.Delgado': 261,
#  "A.Dell'Acqua": 262,
#  "A.Dell'Oro": 263,
#  'A.Dell’Acqua': 264,
#  'A.Denisenko': 265,
#  'A.Denisov': 266,
#  'A.Depasse': 267,
#  'A.Dergacheva': 268,
#  'A.Deshpande': 269,
#  'A.Dexter': 270,
#  'A.DiLeva': 271,
#  'A.Dierlamm': 272,
#  'A.Dimitrievska': 273,
#  'A.Dinklage': 274,
#  'A.Dinnyes': 275,
#  'A.Dion': 276,
#  'A.Dioszegi': 277,
#  'A.Dmitriev': 278,
#  'A.Dobrin': 279,
#  'A.Dombi': 280,
#  'A.Dominguez': 281,
#  'A.Domokos': 282,
#  'A.Donka': 283,
#  'A.Doria': 284,
#  'A.Drees': 285,
#  'A.Droll': 286,
#  'A.Druzd-Sitek': 287,
#  'A.Dubla': 288,
#  'A.Dubreuil': 289,
#  'A.Dudarev': 290,
#  'A.Duperrin': 291,
#  'A.Durglishvili': 292,
#  'A.Durum': 293,
#  'A.D’onofrio': 294,
#  'A.E.Barton': 295,
#  'A.E.Bolz': 296,
#  'A.E.C.Coimbra': 297,
#  'A.E.Dumitriu': 298,
#  'A.E.Gleckl': 299,
#  'A.E.Jaspan': 300,
#  'A.E.Kiryunin': 301,
#  'A.E.McDougall': 302,
#  'A.E.Pace': 303,
#  'A.E.Simon': 304,
#  'A.E.Tolley': 305,
#  'A.EL-ESAWIMOHAMED': 306,
#  'A.Ebrahimi': 307,
#  'A.Effler': 308,
#  'A.Eguchi': 309,
#  'A.Ejlli': 310,
#  'A.Eltner': 311,
#  'A.Emerman': 312,
#  'A.Enokizono': 313,
#  'A.Ereditato': 314,
#  'A.Erikson': 315,
#  'A.Erokhin': 316,
#  'A.Evdokimov': 317,
#  'A.Ezhilov': 318,
#  'A.F.Brooks': 319,
#  'A.F.Casha': 320,
#  'A.F.Helmling-Cornell': 321,
#  'A.F.Lanza': 322,
#  'A.F.Mechler': 323,
#  'A.F.Mohammed': 324,
#  'A.F.Mulone': 325,
#  'A.F.Nassirpour': 326,
#  'A.F.Vargas': 327,
#  'A.F.Webb': 328,
#  'A.F.Wongel': 329,
#  'A.Fantoni': 330,
#  'A.Farbin': 331,
#  'A.Farilla': 332,
#  'A.Farkas': 333,
#  'A.Farrugia': 334,
#  'A.Fasoli': 335,
#  'A.Fasseeh': 336,
#  'A.Fedorova': 337,
#  'A.Feher': 338,
#  'A.Fehr': 339,
#  'A.Fehér': 340,
#  'A.Feliciello': 341,
#  'A.Fell': 342,
#  'A.Fernandez-Galiana': 343,
#  'A.Ferrante': 344,
#  'A.Ferrari': 345,
#  'A.Ferrer': 346,
#  'A.Ferrero': 347,
#  'A.Ferretti': 348,
#  'A.Festanti': 349,
#  'A.Fienga': 350,
#  'A.Filenius': 351,
#  'A.Filipcic': 352,
#  'A.Filipčič': 353,
#  'A.Finkler': 354,
#  'A.Formica': 355,
#  'A.Formicola': 356,
#  'A.Fortier': 357,
#  'A.Francis': 358,
#  'A.Franke': 359,
#  'A.Franz': 360,
#  'A.Freise': 361,
#  'A.Freund': 362,
#  'A.Froehlich': 363,
#  'A.Furs': 364,
#  'A.Földes': 365,
#  'A.G.A.Brown': 366,
#  'A.G.Bogdanchikov': 367,
#  'A.G.Borbely': 368,
#  'A.G.Borbély': 369,
#  'A.G.Buckley': 370,
#  'A.G.Butkevich': 371,
#  'A.G.Goussiou': 372,
#  'A.G.Hernandez': 373,
#  'A.G.Kharlamov': 374,
#  'A.G.Knospe': 375,
#  'A.G.Krivshich': 376,
#  'A.G.Myagkov': 377,
#  'A.G.Rennie': 378,
#  'A.G.T.Ramos': 379,
#  'A.Gabor': 380,
#  'A.Gabrielli': 381,
#  'A.Gal': 382,
#  'A.Gali': 383,
#  'A.Galkowski': 384,
#  'A.Galvan-Gamez': 385,
#  'A.Gandrakotra': 386,
#  'A.Ganguly': 387,
#  'A.Garcia': 388,
#  'A.Garcia-Gutierrez': 389,
#  'A.Garibli': 390,
#  'A.Garofalo': 391,
#  'A.Gary': 392,
#  'A.Gaudiello': 393,
#  'A.Gaur': 394,
#  'A.Gautam': 395,
#  'A.Gavrilyuk': 396,
#  'A.Gennai': 397,
#  'A.Gera': 398,
#  'A.Ghosh': 399,
#  'A.Giammanco': 400,
#  'A.Giannini': 401,
#  'A.Giassi': 402,
#  'A.Giazotto': 403,
#  'A.Giganon': 404,
#  'A.Gillibert': 405,
#  'A.Gilyén': 406,
#  'A.Glandon': 407,
#  'A.Glazov': 408,
#  'A.Gogoleva': 409,
#  'A.Gomes': 410,
#  'A.Gomez': 411,
#  'A.Gongadze': 412,
#  'A.Gopakumar': 413,
#  'A.Goriaev': 414,
#  'A.Gorin': 415,
#  'A.Gorisek': 416,
#  'A.Gorišek': 417,
#  'A.Gottardo': 418,
#  'A.Grado': 419,
#  'A.Grant': 420,
#  'A.Grawunder': 421,
#  'A.Grebenyuk': 422,
#  'A.Grein': 423,
#  'A.Grelli': 424,
#  'A.Grigoryan': 425,
#  'A.Grimaldi': 426,
#  'A.Gritsan': 427,
#  'A.Grosman': 428,
#  'A.Grummer': 429,
#  'A.Guerguichon': 430,
#  'A.Guerrier': 431,
#  'A.Guglielmetti': 432,
#  'A.Guida': 433,
#  'A.Gupta': 434,
#  'A.Guttman': 435,
#  'A.Gyárfás': 436,
#  'A.Gábris': 437,
#  'A.Görlich': 438,
#  'A.Görög': 439,
#  'A.Güven': 440,
#  'A.H.Alawadi': 441,
#  'A.H.Melo': 442,
#  'A.Haas': 443,
#  'A.Hadef': 444,
#  'A.Hagiwara': 445,
#  'A.Harb': 446,
#  'A.Harlenderova': 447,
#  'A.Hart': 448,
#  'A.Hartin': 449,
#  'A.Harton': 450,
#  'A.Hasib': 451,
#  'A.Heger': 452,
#  'A.Heidmann': 453,
#  'A.Heidt': 454,
#  'A.Heinz': 455,
#  'A.Held': 456,
#  'A.Helm': 457,
#  'A.Helmi': 458,
#  'A.Herghelegiu': 459,
#  'A.Higashida': 460,
#  'A.Hingorani': 461,
#  'A.Hinzmann': 462,
#  'A.Hiramoto': 463,
#  'A.Hiyoshi': 464,
#  'A.Hodges': 465,
#  'A.Hoecker': 466,
#  'A.Hoenle': 467,
#  'A.Hollos': 468,
#  'A.Honle': 469,
#  'A.Honma': 470,
#  'A.Hornung': 471,
#  'A.Horvat': 472,
#  'A.Horváth': 473,
#  'A.Horzela': 474,
#  'A.Horzyk': 475,
#  'A.Hoummada': 476,
#  'A.Howling': 477,
#  'A.Hreibi': 478,
#  'A.Hrynevich': 479,
#  'A.Huber': 480,
#  'A.Hutson': 481,
#  'A.Hutton': 482,
#  'A.Hölting': 483,
#  'A.Hönle': 484,
#  'A.I.Maksimov': 485,
#  'A.I.Mincer': 486,
#  'A.I.Morales': 487,
#  'A.I.Sheikh': 488,
#  'A.IMincer': 489,
#  'A.ISheikh': 490,
#  'A.Iagnocco': 491,
#  'A.Iess': 492,
#  'A.Ilg': 493,
#  'A.Iordanova': 494,
#  'A.Isakov': 495,
#  'A.Ivanov': 496,
#  'A.Ivina': 497,
#  'A.Izmaylov': 498,
#  'A.J.Armbruster': 499,
#  'A.J.Bailey': 500,
#  'A.J.Barr': 501,
#  'A.J.Beddall': 502,
#  'A.J.Bevan': 503,
#  'A.J.Bozson': 504,
#  'A.J.Castro': 505,
#  'A.J.Finch': 506,
#  'A.J.Gillett': 507,
#  'A.J.Korn': 508,
#  'A.J.Lankford': 509,
#  'A.J.Mustill': 510,
#  'A.J.Myers': 511,
#  'A.J.Parker': 512,
#  'A.J.Rozas': 513,
#  'A.J.Ruby': 514,
#  'A.J.Tanasijczuk': 515,
#  'A.J.Taylor': 516,
#  'A.J.Vangsted': 517,
#  'A.J.Weinstein': 518,
#  'A.Jalotra': 519,
#  'A.JamesP.Clover': 520,
#  'A.Jinaru': 521,
#  'A.Jofrehei': 522,
#  'A.Jung': 523,
#  'A.Junique': 524,
#  'A.Juodagalvis': 525,
#  'A.Jurczyszyn': 526,
#  'A.Jusko': 527,
#  'A.JusteRozas': 528,
#  'A.Jákli': 529,
#  'A.K.Divakarla': 530,
#  'A.K.Dubey': 531,
#  'A.K.H.Kong': 532,
#  'A.K.Ichikawa': 533,
#  'A.K.Kvam': 534,
#  'A.K.Mehta': 535,
#  'A.K.Morley': 536,
#  'A.K.Prajapati': 537,
#  'A.K.S.Chiang': 538,
#  'A.K.Srivastava': 539,
#  'A.K.Y.Li': 540,
#  'A.K.Yadav': 541,
#  'A.K.Zadrożny': 542,
#  'A.Kaczmarska': 543,
#  'A.Kahn': 544,
#  'A.Kalsi': 545,
#  'A.Kaluza': 546,
#  'A.Kalweit': 547,
#  'A.Kamenshchikov': 548,
#  'A.Kapitány': 549,
#  'A.KarasuUysal': 550,
#  'A.Karki': 551,
#  'A.Kastanas': 552,
#  'A.Kazantsev': 553,
#  'A.Kelić-Heil': 554,
#  'A.Keri': 555,
#  'A.Kertesz': 556,
#  'A.Keskin': 557,
#  'A.Khalilzadeh': 558,
#  'A.Khan': 559,
#  'A.Khanov': 560,
#  'A.Khanzadeev': 561,
#  'A.Kharchilava': 562,
#  'A.Khatiwada': 563,
#  'A.Khatun': 564,
#  'A.Khodinov': 565,
#  'A.Khotjantsev': 566,
#  'A.Khuntia': 567,
#  'A.Kilgallon': 568,
#  'A.Kingan': 569,
#  'A.Kirchhoff': 570,
#  'A.Kirschner': 571,
#  'A.Kisiel': 572,
#  'A.Klimentov': 573,
#  'A.Kluge': 574,
#  'A.Knieps': 575,
#  'A.Knight': 576,
#  'A.Knox': 577,
#  'A.Knue': 578,
#  'A.Kochoska': 579,
#  'A.Kohut': 580,
#  'A.Komócsi': 581,
#  'A.Konaka': 582,
#  'A.Kondratyev': 583,
#  'A.Kontos': 584,
#  'A.Korn': 585,
#  'A.Korotkov': 586,
#  'A.Koshy': 587,
#  'A.Kostin': 588,
#  'A.Kostochka': 589,
#  'A.Kotliarov': 590,
#  'A.Kotsokechagia': 591,
#  'A.Kotwal': 592,
#  'A.Koulouris': 593,
#  'A.Kourkoumeli-Charalampidi': 594,
#  'A.Kovács': 595,
#  'A.Krasznahorkay': 596,
#  'A.Kravcakova': 597,
#  'A.Kravcáková': 598,
#  'A.Kravčáková': 599,
#  'A.Krishnan': 600,
#  'A.Krone-Martins': 601,
#  'A.Krämer-Flecken': 602,
#  'A.Królak': 603,
#  'A.Kubota': 604,
#  'A.Kumar': 605,
#  'A.Kupco': 606,
#  'A.Kurepin': 607,
#  'A.Kurova': 608,
#  'A.Kuryakin': 609,
#  'A.Kutynia': 610,
#  'A.Kyriakis': 611,
#  'A.Kádár': 612,
#  'A.Könies': 613,
#  'A.L.Campos': 614,
#  'A.L.D.Couto': 615,
#  'A.L.Hallin': 616,
#  'A.L.Heggelund': 617,
#  'A.L.James': 618,
#  'A.L.Ko': 619,
#  'A.L.Lionti': 620,
#  'A.L.Maslennikov': 621,
#  'A.L.Mazuecos': 622,
#  'A.L.Miller': 623,
#  'A.L.Piro': 624,
#  'A.L.Read': 625,
#  'A.L.Solis': 626,
#  'A.L.Sopio': 627,
#  'A.L.Steinhebel': 628,
#  'A.L.Stuver': 629,
#  'A.L.Urban': 630,
#  'A.L.Virto': 631,
#  'A.L.desEtangs': 632,
#  'A.LaTorre': 633,
#  'A.Lakrathok': 634,
#  'A.Lallas': 635,
#  'A.Lamberts': 636,
#  'A.Lamperti': 637,
#  'A.Langenberg': 638,
#  'A.Langenbucher': 639,
#  'A.Lanza': 640,
#  'A.Lapertosa': 641,
#  'A.Lardeux': 642,
#  'A.Lartaux-Vollard': 643,
#  'A.Lath': 644,
#  'A.Laudrain': 645,
#  'A.Laurier': 646,
#  'A.Lazzarini': 647,
#  'A.Lebedev': 648,
#  'A.Leisos': 649,
#  'A.Leithner': 650,
#  'A.Lelek': 651,
#  'A.Lemaître': 652,
#  'A.Lenon': 653,
#  'A.Leopold': 654,
#  'A.Lepailleur': 655,
#  'A.Li': 656,
#  'A.Liblong': 657,
#  'A.Lindner': 658,
#  'A.Linss': 659,
#  'A.Lipniacka': 660,
#  'A.Lister': 661,
#  'A.Liu': 662,
#  'A.Lleres': 663,
#  'A.Lobel': 664,
#  'A.Lockwood': 665,
#  'A.Longhin': 666,
#  'A.Longo': 667,
#  'A.LopezSolis': 668,
#  'A.Lorca': 669,
#  'A.Lorenz': 670,
#  'A.Losle': 671,
#  'A.Lounis': 672,
#  'A.Lucotte': 673,
#  'A.Luczay': 674,
#  'A.Lumsdaine': 675,
#  'A.Lászlóffy': 676,
#  'A.Lösle': 677,
#  'A.Lücke': 678,
#  'A.M.Baer': 679,
#  'A.M.Burger': 680,
#  'A.M.C.Glaenzer': 681,
#  'A.M.CharryGiraldo': 682,
#  'A.M.Cooper-Sarkar': 683,
#  'A.M.Csergő': 684,
#  'A.M.Deiana': 685,
#  'A.M.El-Mahalawy': 686,
#  'A.M.Farah': 687,
#  'A.M.Gago': 688,
#  'A.M.Gretarsson': 689,
#  'A.M.H.Correia': 690,
#  'A.M.HenriquesCorreia': 691,
#  'A.M.Henry': 692,
#  'A.M.Holgado': 693,
#  'A.M.Khan': 694,
#  'A.M.Knee': 695,
#  'A.M.Lory': 696,
#  'A.M.Mathis': 697,
#  'A.M.Nairz': 698,
#  'A.M.Piersimoni': 699,
#  'A.M.R.Vera': 700,
#  'A.M.RodriguezVera': 701,
#  'A.M.S.Smith': 702,
#  'A.M.Sickles': 703,
#  'A.M.Sintes': 704,
#  'A.M.Soukharev': 705,
#  'A.M.Toivonen': 706,
#  'A.M.Wang': 707,
#  'A.M.Wharton': 708,
#  'A.M.Zaitsev': 709,
#  'A.M.diGiorgio': 710,
#  'A.MForsea': 711,
#  'A.MacQuet': 712,
#  'A.Macauda': 713,
#  'A.Macchiolo': 714,
#  'A.Macquet': 715,
#  'A.Madar': 716,
#  'A.Maevskaya': 717,
#  'A.Maio': 718,
#  'A.Maire': 719,
#  'A.Maj': 720,
#  'A.Malik': 721,
#  'A.Mann': 722,
#  'A.Manousos': 723,
#  'A.Marantis': 724,
#  'A.MarcellSzász': 725,
#  'A.Marchioro': 726,
#  'A.Margotti': 727,
#  'A.Marin': 728,
#  'A.Markowitz': 729,
#  'A.Marquina': 730,
#  'A.Marton': 731,
#  'A.Marzin': 732,
#  'A.Marín': 733,
#  'A.Maróti': 734,
#  'A.Masip': 735,
#  'A.Masoni': 736,
#  'A.Masserot': 737,
#  'A.Mastbaum': 738,
#  'A.Mastroberardino': 739,
#  'A.Mastrobuono-Battisti': 740,
#  'A.Mastroserio': 741,
#  'A.Matas': 742,
#  'A.Mathis': 743,
#  'A.Matic': 744,
#  'A.Mattarei': 745,
#  'A.Matyja': 746,
#  'A.McGregor': 747,
#  'A.Mefodiev': 748,
#  'A.Mehta': 749,
#  'A.Meier': 750,
#  'A.Melatos': 751,
#  'A.Melzer': 752,
#  'A.Menchaca-Rocha': 753,
#  'A.Menendez-Vazquez': 754,
#  'A.Messineo': 755,
#  'A.Mhaske': 756,
#  'A.Miani': 757,
#  'A.Mihály': 758,
#  'A.Mikeházi': 759,
#  'A.Miklosi': 760,
#  'A.Milic': 761,
#  'A.Milillo': 762,
#  'A.Miller': 763,
#  'A.Millet': 764,
#  'A.Milov': 765,
#  'A.Minamino': 766,
#  'A.Mints': 767,
#  'A.Mirto': 768,
#  'A.Mishchenko': 769,
#  'A.Mishkin': 770,
#  'A.Miucci': 771,
#  'A.Miyamoto': 772,
#  'A.Mizukami': 773,
#  'A.Modak': 774,
#  'A.Moggi': 775,
#  'A.Moitinho': 776,
#  'A.Mollen': 777,
#  'A.Montalbano': 778,
#  'A.Montaner': 779,
#  'A.Mora': 780,
#  'A.More': 781,
#  'A.Moreno': 782,
#  'A.Morozzi': 783,
#  'A.Morsch': 784,
#  'A.Morton': 785,
#  'A.Mucci': 786,
#  'A.Mukherjee': 787,
#  'A.Mukora': 788,
#  'A.Mullavey': 789,
#  'A.Mulliri': 790,
#  'A.Murrone': 791,
#  'A.Mussgiller': 792,
#  'A.N.Flores': 793,
#  'A.N.Fray': 794,
#  'A.N.Karyukhin': 795,
#  'A.N.Khlobystov': 796,
#  'A.N.Mishra': 797,
#  'A.N.Nag': 798,
#  'A.N.Tuna': 799,
#  'A.NagNag': 800,
#  'A.Nagar': 801,
#  'A.Nagler': 802,
#  'A.Nagy': 803,
#  'A.Nakamura': 804,
#  'A.Nassirpour': 805,
#  'A.Nath': 806,
#  'A.Neagu': 807,
#  'A.Negri': 808,
#  'A.Neunzert': 809,
#  'A.Nisati': 810,
#  'A.Nishizawa': 811,
#  'A.Noriega-Crespo': 812,
#  'A.Nyanin': 813,
#  'A.Németh': 814,
#  'A.Nógrádi': 815,
#  'A.Nürnberg': 816,
#  'A.Obertelli': 817,
#  'A.Ochi': 818,
#  'A.Odahara': 819,
#  'A.Ogrodnik': 820,
#  'A.Oh': 821,
#  'A.Ohlson': 822,
#  'A.Olariu': 823,
#  'A.Oldre': 824,
#  'A.Olszewski': 825,
#  'A.Oláh': 826,
#  'A.Onillon': 827,
#  'A.Onnela': 828,
#  'A.Onnerstad': 829,
#  'A.Onofre': 830,
#  'A.OrtizVelasquez': 831,
#  'A.Oskarsson': 832,
#  'A.Ouraou': 833,
#  'A.Ozsvar': 834,
#  'A.P.Colijn': 835,
#  'A.P.Dimmock': 836,
#  'A.P.Ibanez': 837,
#  'A.P.Lundgren': 838,
#  'A.P.Mohanty': 839,
#  'A.P.Morris': 840,
#  "A.P.O'Neill": 841,
#  "A.P.O'neill": 842,
#  'A.P.O’neill': 843,
#  'A.P.P.Peixoto': 844,
#  'A.P.Pages': 845,
#  'A.P.Patel': 846,
#  'A.P.PereiraPeixoto': 847,
#  'A.P.Rouillard': 848,
#  'A.P.Spencer': 849,
#  'A.Pai': 850,
#  'A.Pal': 851,
#  'A.Pal-Singh': 852,
#  'A.Palasciano': 853,
#  'A.Panahi': 854,
#  'A.Panidapu': 855,
#  'A.Paoli': 856,
#  'A.Paolone': 857,
#  'A.Papadopoulos': 858,
#  'A.Paramonov': 859,
#  'A.Pardons': 860,
#  'A.Parida': 861,
#  'A.Parisi': 862,
#  'A.Parisini': 863,
#  'A.Parker': 864,
#  'A.Pasqualetti': 865,
#  'A.Pathak': 866,
#  'A.Patsatsi': 867,
#  'A.Pauls': 868,
#  'A.Pavlov': 869,
#  'A.Pavone': 870,
#  'A.Peck': 871,
#  'A.Pekker': 872,
#  'A.Pele': 873,
#  'A.Penttilä': 874,
#  'A.Perego': 875,
#  'A.Pereira': 876,
#  'A.Perera': 877,
#  'A.Perez': 878,
#  'A.Perloff': 879,
#  'A.Perreca': 880,
#  'A.Perrevoort': 881,
#  'A.Pershin': 882,
#  'A.Petrenko': 883,
#  'A.Petridis': 884,
#  'A.Peyaud': 885,
#  'A.Picazio': 886,
#  'A.Piccinelli': 887,
#  'A.Pieczonka': 888,
#  'A.Piombini': 889,
#  'A.Pizzini': 890,
#  'A.Poley': 891,
#  'A.Policicchio': 892,
#  'A.Polini': 893,
#  'A.Polyák': 894,
#  'A.Pop': 895,
#  'A.Popov': 896,
#  'A.Poves': 897,
#  'A.Pritchard': 898,
#  'A.Privitera': 899,
#  'A.Prša': 900,
#  'A.Puecher': 901,
#  'A.Pukhov': 902,
#  'A.Pun': 903,
#  'A.Puri': 904,
#  'A.Pál': 905,
#  'A.Pór': 906,
#  'A.Pósa': 907,
#  'A.Quadt': 908,
#  'A.Qureshi': 909,
#  'A.R.Back': 910,
#  'A.R.Buzykaev': 911,
#  'A.R.Chomont': 912,
#  'A.R.Cukierman': 913,
#  'A.R.Guimaraes': 914,
#  'A.R.Jones': 915,
#  'A.R.Morales': 916,
#  'A.R.Redelbach': 917,
#  'A.R.Rodriguez': 918,
#  'A.R.Roepe': 919,
#  'A.R.Sahasransu': 920,
#  'A.R.Schmier': 921,
#  'A.R.Timmins': 922,
#  'A.R.Wade': 923,
#  'A.R.Weidberg': 924,
#  'A.R.Williamson': 925,
#  'A.Radu': 926,
#  'A.Rahaman': 927,
#  'A.Rakotozafindrabe': 928,
#  'A.RamirezMorales': 929,
#  'A.Ramos-Buades': 930,
#  'A.Rao': 931,
#  'A.Ray': 932,
#  'A.Rebelo': 933,
#  'A.Recio-Blanco': 934,
#  'A.Rehman': 935,
#  'A.Reichold': 936,
#  'A.Reiman': 937,
#  'A.Reimers': 938,
#  'A.Reiss': 939,
#  'A.Rej': 940,
#  'A.Renardi': 941,
#  'A.Renzini': 942,
#  'A.Rest': 943,
#  'A.Riabov': 944,
#  'A.Rimac': 945,
#  'A.Rimoldi': 946,
#  'A.Rinkevicius': 947,
#  'A.Riva': 948,
#  'A.Rivetti': 949,
#  'A.Rizzi': 950,
#  'A.Robertson': 951,
#  'A.Robson': 952,
#  'A.Rocchi': 953,
#  'A.RodriguezRodriguez': 954,
#  'A.Romaniouk': 955,
#  'A.Romero': 956,
#  'A.Romero-Rodríguez': 957,
#  'A.Roque-Bernard': 958,
#  'A.Rosano': 959,
#  'A.Rossa': 960,
#  'A.Rossi': 961,
#  'A.Rotondi': 962,
#  'A.Roy': 963,
#  'A.Rozanov': 964,
#  'A.Rubbia': 965,
#  'A.Ruiz': 966,
#  'A.Ruiz-Martinez': 967,
#  'A.Rummler': 968,
#  'A.Runov': 969,
#  'A.Rustamov': 970,
#  'A.Rusu': 971,
#  'A.Rybicki': 972,
#  'A.Rychter': 973,
#  'A.Ryd': 974,
#  'A.Ryzhov': 975,
#  'A.Rüdiger': 976,
#  'A.S.Bell': 977,
#  'A.S.Cerqueira': 978,
#  'A.S.Chisholm': 979,
#  'A.S.Drobac': 980,
#  'A.S.Hines': 981,
#  'A.S.Inacio': 982,
#  'A.S.Kozhin': 983,
#  'A.S.Markosyan': 984,
#  'A.S.Menon': 985,
#  'A.S.Mete': 986,
#  'A.S.Nyanin': 987,
#  'A.S.Patron': 988,
#  'A.S.Pineda': 989,
#  'A.S.Safonov': 990,
#  'A.S.Salas': 991,
#  'A.S.Sengupta': 992,
#  'A.S.Sharma': 993,
#  'A.S.Tee': 994,
#  'A.S.Ubhi': 995,
#  'A.S.White': 996,
#  'A.Sahu': 997,
#  'A.Salnikov': 998,
#  'A.Salvucci': 999,
#  ...}

# %% [markdown]
# So there are `32220` unique authors, now having their somewhat correct names.

# %%
"""
THIS IS AN ARTIFACT

    -> HEAVY MEMORY USAGE WITH LINKLIST CONTAINING UUIDS AS STRINGS!

temp_mem = []
temp_link_list = []
r = re.compile(r"\s+", re.MULTILINE)

count = 0
for i in range(len(data['content'])):
    if (i+1) % 10 == 0:
        sys.stdout.write("\r {0} / {1}".format(i+1,len(data['content'])))
        sys.stdout.flush()
    content_mem = []
    for j in range(len(data['content'][i]['authorships'])):
        
        if (data['content'][i]['authorships'][j]['otype'] == 'PersonAuthorship'):
            name_to_add = ''
            string_to_add = '' 
            #using label is not advised due to special characters and its most likely have education description
            #if the field extists, get the name! -> what if none of them exists?
            if 'givenName' in data['content'][i]['authorships'][j]:
                name_to_add += str(data['content'][i]['authorships'][j]['givenName']) + ' '
            if 'familyName' in data['content'][i]['authorships'][j]:
                name_to_add += str(data['content'][i]['authorships'][j]['familyName'])
            
            #uuid_encoded = str(uuid.uuid5( uuid.NAMESPACE_DNS,r.sub("",name_to_add) ) ) -> takes up too much space
            string_to_add += name_to_add + ', '
            string_to_add += uuid_encoded + ', '
            string_to_add += str(data['content'][i]['publishedYear'])
            content_mem.append(uuid_encoded)
            temp_mem.append(string_to_add)
            
    if (len(content_mem) > 0):
        for j in range(len(content_mem)):
            for k in np.arange(i+1,len(content_mem)):
                temp_link_list.append([content_mem[j],content_mem[k]])
                
"""
# Out:
# '\nTHIS IS AN ARTIFACT\n\n    -> HEAVY MEMORY USAGE WITH LINKLIST CONTAINING UUIDS AS STRINGS!\n\ntemp_mem = []\ntemp_link_list = []\nr = re.compile(r"\\s+", re.MULTILINE)\n\ncount = 0\nfor i in range(len(data[\'content\'])):\n    if (i+1) % 10 == 0:\n        sys.stdout.write("\r {0} / {1}".format(i+1,len(data[\'content\'])))\n        sys.stdout.flush()\n    content_mem = []\n    for j in range(len(data[\'content\'][i][\'authorships\'])):\n        \n        if (data[\'content\'][i][\'authorships\'][j][\'otype\'] == \'PersonAuthorship\'):\n            name_to_add = \'\'\n            string_to_add = \'\' \n            #using label is not advised due to special characters and its most likely have education description\n            #if the field extists, get the name! -> what if none of them exists?\n            if \'givenName\' in data[\'content\'][i][\'authorships\'][j]:\n                name_to_add += str(data[\'content\'][i][\'authorships\'][j][\'givenName\']) + \' \'\n            if \'familyName\' in data[\'content\'][i][\'authorships\'][j]:\n                name_to_add += str(data[\'content\'][i][\'authorships\'][j][\'familyName\'])\n            \n            #uuid_encoded = str(uuid.uuid5( uuid.NAMESPACE_DNS,r.sub("",name_to_add) ) ) -> takes up too much space\n            string_to_add += name_to_add + \', \'\n            string_to_add += uuid_encoded + \', \'\n            string_to_add += str(data[\'content\'][i][\'publishedYear\'])\n            content_mem.append(uuid_encoded)\n            temp_mem.append(string_to_add)\n            \n    if (len(content_mem) > 0):\n        for j in range(len(content_mem)):\n            for k in np.arange(i+1,len(content_mem)):\n                temp_link_list.append([content_mem[j],content_mem[k]])\n                \n'

# %%
len(np.unique(temp_mem)), len(temp_mem)
# Out:
# (1, 31149)

# %%
_,app_count = np.unique(temp_mem, return_counts=True)
np.unique(app_count, return_counts=True)
# Out:
# (array([1], dtype=int64), array([1], dtype=int64))

# %%
_,app_count = np.unique(temp_mem2, return_counts=True)
np.unique(app_count, return_counts=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SZABDM~1\AppData\Local\Temp/ipykernel_11412/1322861431.py in <module>
# ----> 1 _,app_count = np.unique(temp_mem2, return_counts=True)
#       2 np.unique(app_count, return_counts=True)
#
# NameError: name 'temp_mem2' is not defined

# %% [markdown]
# Sooooo, `mtid` is unique to the creation of such object...
#
# Old trick: use their name as a source for the uuid to hide their identity, while it is deterministic. The logic of choosing a uuid will be hidden though.

# %%
data['content'][0]['authorships'][0]
# Out:
# {'otype': 'PersonAuthorship',
#  'mtid': 99807928,
#  'link': '/api/authorship/99807928',
#  'label': 'Aad, G',
#  'listPosition': 1,
#  'share': 0.0,
#  'first': True,
#  'last': False,
#  'corresponding': False,
#  'familyName': 'Aad',
#  'givenName': 'G',
#  'authorTyped': True,
#  'editorTyped': False,
#  'otherTyped': False,
#  'type': {'otype': 'AuthorshipType',
#   'mtid': 1,
#   'link': '/api/authorshiptype/1',
#   'label': 'Szerző',
#   'code': 0,
#   'published': True,
#   'oldId': 0,
#   'snippet': True},
#  'published': False,
#  'snippet': True}

# %% [markdown]
# ## UUID.UUID5 for hiding information ( Removed )
#
# I will be using uuid.uuid5 for hidin information to hide personal information for the sake of clean analysis. Later on we can insert such information back, take a look at it and draw conclusions.

# %%
print(uuid.uuid5(uuid.NAMESPACE_DNS,(data['content'][0]['authorships'][0]['givenName'] +
                                     ' ' +
                                     data['content'][0]['authorships'][0]['familyName'])))
# Out:
# 61977f7f-ec8f-5de5-8a2f-e476a11c4455

# %%
"""
temp_mem = []
temp_link_list = []
r = re.compile(r"\s+", re.MULTILINE)

count = 0
for i in range(len(data['content'])):
    if (i+1) % 10 == 0:
        sys.stdout.write("\r {0} / {1}".format(i+1,len(data['content'])))
        sys.stdout.flush()
    content_mem = []
    for j in range(len(data['content'][i]['authorships'])):
        
        if (data['content'][i]['authorships'][j]['otype'] == 'PersonAuthorship'):
            name_to_add = ''
            string_to_add = '' 
            #if the field extists, get the name! -> what if none of them exists?
            if 'givenName' in data['content'][i]['authorships'][j]:
                name_to_add += str(data['content'][i]['authorships'][j]['givenName']) + ' '
            if 'familyName' in data['content'][i]['authorships'][j]:
                name_to_add += str(data['content'][i]['authorships'][j]['familyName'])
            
            uuid_encoded = str(uuid.uuid5( uuid.NAMESPACE_DNS,r.sub("",name_to_add) ) )
            string_to_add += name_to_add + ', '
            string_to_add += uuid_encoded + ', '
            string_to_add += str(data['content'][i]['publishedYear'])
            content_mem.append(uuid_encoded)
            temp_mem.append(string_to_add)
            
    if (len(content_mem) > 0):
        for j in range(len(content_mem)):
            for k in np.arange(i+1,len(content_mem)):
                temp_link_list.append([content_mem[j],content_mem[k]])
"""
# Out:
# '\ntemp_mem = []\ntemp_link_list = []\nr = re.compile(r"\\s+", re.MULTILINE)\n\ncount = 0\nfor i in range(len(data[\'content\'])):\n    if (i+1) % 10 == 0:\n        sys.stdout.write("\r {0} / {1}".format(i+1,len(data[\'content\'])))\n        sys.stdout.flush()\n    content_mem = []\n    for j in range(len(data[\'content\'][i][\'authorships\'])):\n        \n        if (data[\'content\'][i][\'authorships\'][j][\'otype\'] == \'PersonAuthorship\'):\n            name_to_add = \'\'\n            string_to_add = \'\' \n            #if the field extists, get the name! -> what if none of them exists?\n            if \'givenName\' in data[\'content\'][i][\'authorships\'][j]:\n                name_to_add += str(data[\'content\'][i][\'authorships\'][j][\'givenName\']) + \' \'\n            if \'familyName\' in data[\'content\'][i][\'authorships\'][j]:\n                name_to_add += str(data[\'content\'][i][\'authorships\'][j][\'familyName\'])\n            \n            uuid_encoded = str(uuid.uuid5( uuid.NAMESPACE_DNS,r.sub("",name_to_add) ) )\n            string_to_add += name_to_add + \', \'\n            string_to_add += uuid_encoded + \', \'\n            string_to_add += str(data[\'content\'][i][\'publishedYear\'])\n            content_mem.append(uuid_encoded)\n            temp_mem.append(string_to_add)\n            \n    if (len(content_mem) > 0):\n        for j in range(len(content_mem)):\n            for k in np.arange(i+1,len(content_mem)):\n                temp_link_list.append([content_mem[j],content_mem[k]])\n'

# %%
#apps,app_count = np.unique(temp_mem, return_counts=True)
#c1,c2 = np.unique(app_count, return_counts=True)

#print(len(apps), len(c1),len(c2))

# %% [markdown]
# This makes it obvious that the encoded gives the same result as the not encoded, meaning that using their name is acceptable to create the decoding list and the linklist with dates included.

# %% [markdown]
# ## NP.UINT32
#
# To encode the list, this is more efficient compared to uuids as strings. Of course, the uuid generation is done on the fly, which is fast compared to searching for the encoding integer in an already existing array.

# %%
np.array(list(temp_mem.keys()))[np.array(list(temp_mem.keys())) == 'GAad']
# Out:
# array(['GAad'], dtype='<U47')

# %%
np.array(list(temp_mem.values()))
# Out:
# array([    0,     1,     2, ..., 31146, 31147, 31148], dtype=uint32)

# %%
data['content'][0]['authorships'][0]['givenName'] + data['content'][0]['authorships'][0]['familyName']
# Out:
# 'GAad'

# %%
data['content'][0]['authorCount']
# Out:
# 2870

# %%
_name_list = np.array(list(temp_mem.keys()))      #saving tables
_encoded_list = np.array(list(temp_mem.values())) 
temp_link_list = np.zeros((0,4), dtype=np.uint32) #burning in datatype
r = re.compile(r"\s+", re.MULTILINE)              #for stripping some stuff

count = 0
for i in range(len(data['content'])):
    if (i+1) % 10 == 0:
        sys.stdout.write("\r {0} / {1} # {2}".format(i+1,len(data['content']), len(temp_link_list)))
        sys.stdout.flush()
    content_mem = []
    for j in range(len(data['content'][i]['authorships'])):
        
        if (data['content'][i]['authorships'][j]['otype'] == 'PersonAuthorship'):
            name_to_add = ''
            string_to_add = '' 
            #if the field extists, get the name! -> what if none of them exists?
            if 'givenName' in data['content'][i]['authorships'][j]:
                name_to_add += str(data['content'][i]['authorships'][j]['givenName']) + ' '
            if 'familyName' in data['content'][i]['authorships'][j]:
                name_to_add += str(data['content'][i]['authorships'][j]['familyName'])
            name_to_add = r.sub("", name_to_add)
            _encoded = _encoded_list[_name_list == name_to_add]
            if len(_encoded) == 1:
                content_mem.append(_encoded[0])
            else:
                print("Wrong amount of authors: {} != 1 !".format(len(_encoded)))
            
    if (len(content_mem) > 0):
        tmp_mem = []     #save partial results as constans addition is not liked by numpy
        for j in range(len(content_mem)):
            for k in np.arange(j+1,len(content_mem)):
                tmp_mem.append([content_mem[j],content_mem[k],data['content'][i]['publishedYear'],data['content'][i]['authorCount']])
        if (len(tmp_mem) > 0): 
            temp_link_list = np.append(temp_link_list,
                                       tmp_mem,
                                       axis=0)
            
temp_link_list = np.array(temp_link_list, dtype=np.uint32)
# Out:
#  5000 / 5000 # 89197084

# %%
len(temp_link_list)
# Out:
# 89197084

# %%
temp_link_list = np.array(temp_link_list, dtype=np.uint32)

# %%
temp_link_list[0]
# Out:
# array([10068,  3638,  2021,  2870], dtype=uint32)

# %%
len(temp_link_list)
# Out:
# 89197084

# %%
len(temp_link_list) / len(apps)**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SZABDM~1\AppData\Local\Temp/ipykernel_11412/172812328.py in <module>
# ----> 1 len(temp_link_list) / len(apps)**2
#
# NameError: name 'apps' is not defined

# %%
temp_link_list[:,0:2].shape
# Out:
# (89197084, 2)

# %%
len(temp_link_list[temp_link_list[:,3] < 200])
# Out:
# 350046

# %% [markdown]
# **DO NOT SAVE IT IN THIS FORM!**

# %%
#np.savetxt('data/decoding_s_5000.csv', temp_mem, delimiter=",",fmt='%s',encoding="utf-8")
#np.savetxt('data/sample5000.csv', temp_link_list, delimiter=",",fmt='%s',encoding="utf-8")

# %% [markdown]
# This seems huge but... I don't think this is a bad or wrong result, because there are a couple of mass co-athor publiations, which comes with a fully connecter graph that is jus huge in itsef.

# %%
170000000 * 2 * 32 /1024 / 8 / 1024 / 1024
# Out:
# 1.2665987014770508

# %%
638 * 1906 * 1060 * 3 * 2 / 1024 / 1024 / 1024
# Out:
# 7.202791124582291

# %%
temp_link_list[:,0:2].flatten().shape
# Out:
# (178394168,)

# %% [markdown]
# ## Degree Distribution

# %%
np.unique(temp_link_list[:,0:2].flatten())


plt.figure(figsize=(14,7))

plt.title("Degree Distribution\n5000 freshest publications", fontsize=24)

_, deg = np.unique(temp_link_list[:,0:2].flatten(), return_counts=True)
plt.hist(deg, bins=101, color="red")

plt.xlabel("Degree", fontsize=20)
plt.ylabel("Occurence", fontsize=20)
plt.tick_params(labelsize=18,axis="both",size=17)

plt.yscale("log")
plt.grid(linestyle="--")

plt.savefig("figs/k_dist_from_5000sample.pdf",format="pdf",bbox_inches="tight")
plt.show()

# %%
np.unique(temp_link_list[:,0:2].flatten())


plt.figure(figsize=(14,7))

plt.title("Degree Distribution\n5000 freshest publications with cutoff", fontsize=24)


_, deg = np.unique(temp_link_list[:,0:2][temp_link_list[:,3] < 200].flatten(), return_counts=True)
plt.hist(deg, bins=101, color="red")

plt.xlabel("Degree", fontsize=20)
plt.ylabel("Occurence", fontsize=20)
plt.tick_params(labelsize=18,axis="both",size=17)

plt.yscale("log")
plt.grid(linestyle="--")

plt.savefig("figs/k_dist_from_5000sample_cutoff.pdf",format="pdf",bbox_inches="tight")
plt.show()

# %% [markdown]
# Its interesting how it looks like it's scale-free, so the shape is retained even with the cutoff.

# %% [markdown]
# ## Other data for network creation
#
# Not only collaborating authorscan be connected together, but they can be connected to topics that they are like to "work in" or prefer.
#
# ### Subjects-author bipartite network
#
# A subject is a topic that is general enough to not specify what it is about. Like `Physics`. Physics is about a lot of things while we generally understand when someone says "he studies physics". In this sense it can be understood as a general topic.

# %%
data['content'][0]['subjects']
# Out:
# [{'otype': 'Classification',
#   'mtid': 10154,
#   'link': '/api/classification/10154',
#   'label': 'Fizika',
#   'published': True,
#   'snippet': True}]

# %%
subjects = []
sub_author_links = []
for i in range(len(data['content'])):
    for j in range(len(data['content'][i]['subjects'])):
        subjects.append(data['content'][i]['subjects'][j]['label'])
        
distinctSubs, dSubCount = np.unique(subjects, return_counts=True)
print("There are {} unique subjects, {} where found.".format(len(distinctSubs), len(subjects) ) )

distinctSubs = dict(zip(distinctSubs, np.arange(len(distinctSubs)) + 200000)) #arbitrarily choose a high number
Subs = np.array(list(distinctSubs.keys()))
_eSubs = np.array(list(distinctSubs.values()))

for i in range(len(data['content'])):
    if (i+1) % 10 == 0:
        sys.stdout.write("\r {0} / {1} # {2}".format(i+1,len(data['content']), len(sub_author_links)))
        sys.stdout.flush()
    for j in range(len(data['content'][i]['subjects'])):
        _s_encoded = _eSubs[data['content'][i]['subjects'][j]['label'] == Subs]
        for k in range(len(data['content'][i]['authorships'])):
            if (data['content'][i]['authorships'][k]['otype'] == 'PersonAuthorship'):
                name_to_add = ''
                string_to_add = '' 
                #if the field extists, get the name! -> what if none of them exists?
                if 'givenName' in data['content'][i]['authorships'][k]:
                    name_to_add += str(data['content'][i]['authorships'][k]['givenName']) + ' '
                if 'familyName' in data['content'][i]['authorships'][k]:
                    name_to_add += str(data['content'][i]['authorships'][k]['familyName'])
                name_to_add = r.sub("", name_to_add)
                _encoded = _encoded_list[_name_list == name_to_add]
                if len(_encoded) == 1:
                    sub_author_links.append([_encoded[0], _s_encoded[0]])
                    
                    
sub_author_links = np.array(sub_author_links, dtype=np.uint32)
# Out:
# There are 893 unique subjects, 9127 where found.
#  5000 / 5000 # 117736

# %%
subjects_graph = nx.Graph()

subjects_graph.add_edges_from(sub_author_links)

# %%
pos0 = nx.spring_layout(subjects_graph,iterations=30) #limit the iteration -> at 20 it looks fine too

# %%
fig = plt.figure(figsize=(22,22))

plt.title("Subject-Author Network from Sample:\n Freshest 5000 publications", fontsize=34)

nx.draw_networkx_nodes(subjects_graph,
                      pos0,
                      nodelist = np.array(subjects_graph.nodes)[np.array(subjects_graph.nodes) > 199999],
                      node_size=12,
                      node_color='black',
                      alpha=0.7
                      )

nx.draw_networkx_nodes(subjects_graph,
                      pos0,
                      nodelist = np.array(subjects_graph.nodes)[np.array(subjects_graph.nodes) < 199999],
                      node_size=10,
                      node_color='cyan',
                      alpha=0.7
                      )

nx.draw_networkx_edges(subjects_graph,
                      pos0,
                      width=0.5,
                      edgelist=sub_author_links,
                      edge_color='r',
                      arrows=False)

fig.tight_layout()


plt.savefig("figs/subject_author_network_from_5000sample.pdf", format="pdf", bbox_inches="tight")

#needs some modifications, but starts to look acceptable

plt.show()

# %%
plt.figure(figsize=(14,7))

plt.title("Subject-Author Network\nAuthor Degree Distribution", fontsize=24)

_,degs = np.unique(sub_author_links[:,0], return_counts=True)
plt.hist(degs, bins=101, color="magenta")

plt.xlabel("Degree", fontsize=20)
plt.ylabel("Occurence", fontsize=20)
plt.tick_params(labelsize=18,axis="both",size=17)

plt.yscale("log")
plt.grid(linestyle="--")

plt.savefig("figs/2authofsub_auth_degreedist.pdf",format="pdf",bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(14,7))

plt.title("Subject-Author Network\nSubjects Degree Distribution", fontsize=24)

_,degs = np.unique(sub_author_links[:,1], return_counts=True)
plt.hist(degs, bins=101, color="magenta")

plt.xlabel("Degree", fontsize=20)
plt.ylabel("Occurence", fontsize=20)
plt.tick_params(labelsize=18,axis="both",size=17)

plt.yscale("log")
plt.grid(linestyle="--")

plt.savefig("figs/2subofsub_auth_degreedist.pdf",format="pdf",bbox_inches="tight")
plt.show()

# %%
asd,degs = np.unique(sub_author_links[:,0], return_counts=True)
print(_name_list[asd[degs == max(degs)][0]])
# Out:
# ZoltánBabucs

# %%
atest = np.array([1,2,3,4,3,2])
print(np.argmax(atest))
# Out:
# 3

# %% [markdown]
# ### Keyword - author bipartite network
#
# Obviously this makes less sense, but it is usable to know which extended topic is preferred by authors, its more specified, mor keywords can be present in this network. Filling out this field seems to be arbitrary compared to subjects, which is obligatory to be filled.
#
# **Not doing it as it takes a huge amount of time to actually draw these networks... maybe later on**

# %%
data['content'][1]['keywords']
# Out:
# [{'otype': 'Keyword',
#   'mtid': 1026050,
#   'link': '/api/keyword/1026050',
#   'label': 'dark matter',
#   'published': True,
#   'oldId': 1026050,
#   'snippet': True},
#  {'otype': 'Keyword',
#   'mtid': 1109134,
#   'link': '/api/keyword/1109134',
#   'label': 'Pair production',
#   'published': True,
#   'oldId': 1109134,
#   'snippet': True},
#  {'otype': 'Keyword',
#   'mtid': 1404870,
#   'link': '/api/keyword/1404870',
#   'label': 'Hadron-Hadron scattering (experiments)',
#   'published': True,
#   'oldId': 1404870,
#   'snippet': True},
#  {'otype': 'Keyword',
#   'mtid': 1427623,
#   'link': '/api/keyword/1427623',
#   'label': 'PLUS PLUS',
#   'published': True,
#   'oldId': 1427623,
#   'snippet': True}]

# %%
keywords = []
for i in range(len(data['content'])):
    if 'keywords' in data['content'][i].keys():
        for j in range(len(data['content'][i]['keywords'])):
            keywords.append(data['content'][i]['keywords'][j]['label'])
        
distinctKeys, dKeyCount = np.unique(keywords, return_counts=True)


print("There are {} unique subjects, {} where found.".format(len(distinctKeys), len(keywords) ) )
print(len(distinctKeys), distinctKeys[0:10])
# Out:
# There are 3012 unique subjects, 3360 where found.
# 3012 ["'Components model of addiction'" '(C, alpha(n)) means'
#  '1 new combination' '14 new species' '1848. március 15' '1ST REPORT'
#  '1ST STARS' '25(OH)-vitamin D' '3-interaction' '3D nyomtatás']

# %% [markdown]
# # Network Objects
#
# Networkx for the win! I used it a couple of times, but rarely, meaning that I need a quic recap for it.
#
# ## Test Network initialized

# %%
test_graph = nx.Graph()

test_links = np.array([[1,2],
                       [2,3],
                       [1,3],
                       [4,4],
                      [5,5],
                      [6,6]])

test_graph.add_edges_from(test_links)

# %%
#test plot 
fig = plt.figure(figsize=(7,7))

plt.title("Test Network: Test plot", fontsize=22)

pos = nx.spring_layout(test_graph)

nx.draw_networkx_nodes(test_graph,
                      pos,
                      nodelist = np.array(test_graph.nodes)
                      )

nx.draw_networkx_edges(test_graph,
                      pos,
                      width=0.5,
                      edge_color='r',
                      arrows=False)
fig.tight_layout()

plt.show()

# %% [markdown]
# So I could, in theory, contain all authors from all publications, but seems **unnecessary**.

# %% [markdown]
# ## Creating the network from temp_link_list
#
# Its huge in size, its massive, will netx handle it? Probably not...

# %%
sample_graph = nx.Graph()

sample_graph.add_edges_from(temp_link_list[:,0:2][temp_link_list[:,3] < 200])

# %%
fig = plt.figure(figsize=(22,22))

plt.title("Test Sample: Freshest 5000 publications", fontsize=34)

pos = nx.spring_layout(sample_graph)

nx.draw_networkx_nodes(sample_graph,
                      pos,
                      nodelist = np.array(sample_graph.nodes),
                      node_size=7,
                      alpha=0.7
                      )

nx.draw_networkx_edges(sample_graph,
                      pos,
                      width=0.5,
                      edgelist=temp_link_list[:,0:2][temp_link_list[:,3] < 200],
                      edge_color='r',
                      arrows=False)

fig.tight_layout()

plt.savefig("figs/networkx_from_5000sample.pdf", format="pdf", bbox_inches="tight")

#needs some modifications, but starts to look acceptable

plt.show()

# %%
asd = np.unique(temp_mem)
print(len(asd))
# Out:
# 1

# %%
sub_asd = []
for i in range(len(asd)):
    sub_asd.append(asd[i].split()[-2].replace(',',''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SZABDM~1\AppData\Local\Temp/ipykernel_11412/843267989.py in <module>
#       1 sub_asd = []
#       2 for i in range(len(asd)):
# ----> 3     sub_asd.append(asd[i].split()[-2].replace(',',''))
#
# AttributeError: 'dict' object has no attribute 'split'

# %% [markdown]
# Still not ghood enough fo memory -> going into number territory... (this got implemented)

# %%
import igraph

# %%
iSampleG = igraph.Graph()

iSampleG.add_vertices(sub_asd)
iSampleG.add_edges(temp_link_list)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# C:\Users\SZABDM~1\AppData\Local\Temp/ipykernel_15368/3973478350.py in <module>
#       2
#       3 iSampleG.add_vertices(sub_asd)
# ----> 4 iSampleG.add_edges(temp_link_list)
#
# E:\ANACONDA\conda\lib\site-packages\igraph\__init__.py in add_edges(self, es, attributes)
#     374         """
#     375         eid = self.ecount()
# --> 376         res = GraphBase.add_edges(self, es)
#     377         n = self.ecount() - eid
#     378         if (attributes is not None) and (n > 0):
#
# MemoryError: Error at src/graph/type_indexededgelist.c:307: cannot add edges. -- Out of memory
